# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHANTH-wq/fmml-jan-/blob/main/Day_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2 as cv

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-fb9097fc-806f-4ac4-9a71-28b399b8a8f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb9097fc-806f-4ac4-9a71-28b399b8a8f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bonafide 3.jpeg to bonafide 3.jpeg
# ...

# %%
orig_image = cv.imread('bonafide 3.jpeg', 0)

# %%
orig_image.shape
# Out:
# (1200, 1600)

# %%
cv.imwrite('gray-blur.png', orig_image)
# Out:
# True

# %%
plt.imshow(orig_image)

# %%
portion_image = orig_image[190:290, 250:350]

# %%
plt.imshow(portion_image)

# %%
blurred_image = cv.blur(portion_image, (10, 10))

# %%
plt.imshow(blurred_image)

# %%
blurred_image.shape
# Out:
# (100, 100)

# %%
orig_image[190:290, 250:350] = blurred_image

# %%
plt.imshow(orig_image)

# %%
cv.imwrite('blurred_image.png', orig_image)
# Out:
# True
